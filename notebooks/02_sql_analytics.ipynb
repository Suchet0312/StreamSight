# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("../streamsight.db")

# %%
users_clean.to_sql(
    "users",
    conn,
    if_exists="replace",
    index=False
)

movies_clean.to_sql(
    "movies",
    conn,
    if_exists="replace",
    index=False
)

ratings_clean.to_sql(
    "ratings",
    conn,
    if_exists="replace",
    index=False
)
